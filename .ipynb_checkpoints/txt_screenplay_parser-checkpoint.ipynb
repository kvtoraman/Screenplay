# %%
import docx2txt
import string

# %%
tmp_lines = []
def isAllCaps(line):
    for ch in line:
        if(ch.islower()):
            return False
    return True
def isActionWithOneLinebreak(line):
    if line == "":
        return True
    if line[0] =='(' or line[-1] ==')' or line[-1] != '.':
        return False
    
    if not isName(line):
        return True
        
    return False
def checkNext3Lines(i,lines):
    return (isActionWithOneLinebreak(lines[i+1]) and 
    isActionWithOneLinebreak(lines[i+2]) and
    isActionWithOneLinebreak(lines[i+3]))
def checkPrevious3Lines(i,lines):
    return (isActionWithOneLinebreak(lines[i-1]) and 
    isActionWithOneLinebreak(lines[i-2]) and
    isActionWithOneLinebreak(lines[i-3]) and
    not isName(lines[i-4]))

def isSceneChanger(line):#deteck scene changer lines
    sc_list = ["EXT.","INT.","DECK "," - ","ROOM","ELEVATOR","ON THE ","SLAM TO","INT/EXT","TITLE",'TRANSITION TO',
               'LATER','NIGHT','THAT','APARTMENT','CUT TO']
    for sc in sc_list:
        if(sc in line):
            return True
    return False
def checkPreviousNonemptyLine(i,lines):
    #print(lines[i],"returns")
    while(lines[i-1] == ""):
        i -= 1
    i -= 1
    if i ==0:
        return True
    if lines[i][0] =='(' and lines[i][-1] ==')':
        return True
    if isName(lines[i]):
        return True
    #print('False')
    return False
    
def isAction(i,lines):
    debug_line = 800
    #print("i-1,i-3=>",lines[i-1] , lines[i-2] , lines[i-3])
    if debug_line+200>i>debug_line:
        print("try.. ",i,lines[i])
    if(lines[i] == "" or i<4):
        return False
    if(i+3>=len(lines)):
        return False
    i -= 1
    while(i>0 and lines[i] != ""):
        i -= 1
    #this line should give the answer
    if isName(lines[i+1]):
        return False
    else:
        return True
    if( debug_line+200>i>debug_line ):
        print(lines[i])
    #if("--" in lines[i]):
     #   return False
    if lines[i][-1] == '?' or lines[i][0].islower():
        return False
    if lines[i] == ' ' or lines[i] == '\t':
        return True
    if('(' is lines[i][0] or ')' is lines[i][-1]):
        return False
    if isName(lines[i-1]) or isName(lines[i-2]) or isName(lines[i-3]):
        return False
    if(isAllCaps(lines[i])):
        if ('!!' in lines[i] or lines[i][-1] == '.'):
            return True
        return False
    if( debug_line+200>i>debug_line ):
        print(lines[i])
    if(checkPrevious3Lines(i,lines)):
        if(checkNext3Lines(i,lines)):
    #        if(len(lines[i])<3):
    #            print('-',len(lines[i]),'-',lines[i],'-')
            if(not lines[i][1].isupper()):
                if debug_line+200>i>debug_line:
                    print("still try.. ",i,lines[i])
                if(checkPreviousNonemptyLine(i,lines)):
                    return False
                if(lines[i-4] == ""):
                    return True
                return True
    if( debug_line+200>i>debug_line ):
        print(lines[i])
    if isSceneChanger(lines[i-4]):
        return True
    if lines[i][0].islower():
        return False
    words_in_line = lines[i].split()
    for word in words_in_line:
        if(isName(word)):
            return True
        
    return False
def isName(name):
    if not isAllCaps(name):
        return False
    if isSceneChanger(name):
        return False
    if len(name)<3:
        return False
    return True
#todo:checks whether the file has errors or not
def errorInFile(lines):
    for line in lines:
        if(bool("(" in line) != bool(")" in line)):
            pass
            #print("(" in line , ")" in line)
            #print(line)
            #return True
    return False

# %%
MOVIE_NAME = "Taxi Driver"
DOCX_NAME = "taxidriver" #without extension

# %%
#for txt
my_text = open(DOCX_NAME+'.txt').read()
lines = my_text.split('\n')
out = open(DOCX_NAME + "_out.txt","w")
txtfile = open(DOCX_NAME + "_modified.txt","w")
orgfile = open(DOCX_NAME+ "_original.txt","w")
print("Movie:",MOVIE_NAME,"Screenplay:",DOCX_NAME)
discovery = 1
if(errorInFile(lines)):
    print("ERROR IN FILE")
    exit(1)
tmp_lines = []
print('printing original file to txt..')
for i,line in enumerate(lines):
    orgfile.write(lines[i]+'\n')
#remove tabs,(MORE),pagenumbers from text    
print("Modifing the file...")
for i,line in enumerate(lines):
    lines[i] = lines[i].replace("’","'")
    lines[i] = lines[i].replace('(MORE)','')#replace all (MORE)
    lines[i] = lines[i].replace('EXT:','EXT.') # default is 'EXT.', not 'EXT:'
    lines[i] = lines[i].replace("cont'd","CONT'D")
    lines[i] = lines[i].replace('JEEPERS CREEPERS','') #exception for 1 movie..
    if(lines[i]==''):
        continue
    lines[i] = lines[i].replace('\t',' ')#replace all tab characters with space
    if '03.18.14' in lines[i]:
        lines[i] = ''
    direction_list = ['ROOFTOP',"OMITTED",'(ECU)',"Shooting Script","CONTINUED",'BACK TO','CLOSE ON','DISSOLVE TO',
                      'ONSCREEN','FADE','TO CAMERA','CLOSEUP']
    for elem in direction_list:
        if(elem in lines[i]):
            lines[i] = ''
            break;
    if("(CONT'D)" in lines[i] and lines[i][-8:] != "(CONT'D)"):
        #print(lines[i])
        cont_splitted = lines[i].split("(CONT'D)")
        lines[i] = cont_splitted[0]
        lines.insert(i+1,"")
        lines.insert(i+2,cont_splitted[1][1:])
        #fix?
for i,line in enumerate(lines):
    #print(lines[i])
    if(len(lines[i])<1):
        continue
    while(len(lines[i])>=1 and lines[i][0] == ' '):#remove space if it's the first character
        #print("tab:",lines[i])
        lines[i] = lines[i][1:]
        #print("aft:",lines[i])
    if(2<=len(lines[i])<=5 and lines[i][-1] == '.' and  lines[i][:-1].isdigit()):#replace pagenumbers
        #print("page:",lines[i])
        lines[i] = ""
        continue
    if(1<=len(lines[i])<=4 and lines[i].isdigit()):#replace pagenumbers
        #print("page:",lines[i])
        lines[i] = ""
        continue    
    if(lines[i] != "" and ')' in lines[i] and '(' not in lines[i]):#find parantheticals that occupy more than oneline,merge them
        open_id = i
        #print("=>",lines[i-1],lines[i])
        while('(' not in lines[open_id]):
            open_id -= 1
        new_line = lines[open_id]+" "+lines[i]
        #print(new_line)
        for j in range(open_id,i+1):
            lines[j] = ""
        lines.insert(open_id,new_line)
    lines[i] = lines[i].replace('(voice over)','(V.O.)')
    if(lines[i][0:4] == "(O.S" or lines[i][0:4] == "(V.O"):# if O.S or V.O is the beginning of a line, append it to its speaker
        lines[i-2] +=" "+ lines[i]
        lines[i] = lines[i-2]
    
        
test = 988
#print("%".join(lines[test-10:test+10]))
print("Remove unnecassary action(direction)s")

for i,line in enumerate(lines):
    #remove action(direction)'s and 3 '\n' after them
    if(isAction(i,lines)):
    #    print(i,lines[i])
        continue
        #del lines[i:i+4]
        
    else:
        tmp_lines.append(lines[i])
    #if i > 1000:
     #   break
lines = tmp_lines
#print modified file to check
for i,line in enumerate(lines):
    txtfile.write(line+"\n")
print("Parsing..")
to_be_printed = []
for i,line in enumerate(lines):
    if('(' in line):
        if(isAllCaps(line)):
            continue
        if(line[0]=='(' and line[-1]==')' and line[1:10] == 'copyright'):
            continue
        if("CONT'D" not in line and "O.S." not in line and "V.O" not in line and "MORE" not in line):
            pre_emotion_empty_count = 0
            pre_step = 0
            pre_name_count = 0
            result = []
        
            while(pre_name_count < 1 or len(lines[i - pre_step]) < 3 or  not  isAllCaps(lines[i-pre_step])):
                if isAllCaps(lines[i-pre_step]) and len(lines[i-pre_step]) > 0:
                    pre_name_count += 1
                pre_step += 1
            if(isSceneChanger(lines[i-pre_step])):
                result.append("")
                result.append("")
                result.append("")
                pre_step-=1
                while(lines[i-pre_step] == ""):
                    pre_step-=1
                
            post_emotion_empty_count = 0
            post_step = 0
            post_name_count = 0

            while(post_name_count < 2 or len(lines[i + post_step]) < 3 or  not  isAllCaps(lines[i+post_step]) ):
                if isSceneChanger(lines[i+post_step]) :
                    break
                if isAllCaps(lines[i+post_step]) and len(lines[i+post_step]) > 0:
                    post_name_count += 1
                post_step += 1
            while isSceneChanger(lines[i+post_step]):
                post_step -=1
            
            #print(lines[i-pre_step:i+post_step])
            #print(pre_step,post_step)
            printed_lines = lines[i-pre_step:i+post_step]
            
            for line_in_range in lines[i-pre_step:i+post_step]:
                if(line_in_range!="" and not line_in_range[:-1].isnumeric()):
                    if(line_in_range!="(O.S.)"):
                        if(len(result)%3 == 1 and result[-1][0] != '(' and line_in_range[0]!='('):
                            result.append("")
                        result.append(line_in_range)
            name_utterance = []
            tmp_utterance = "%%%"
            for x in result:
                if(isName(x)):
                    if(tmp_utterance != "%%%"):
                        name_utterance.append(tmp_utterance)
                    tmp_utterance = ""
                    name_utterance.append(x)
                else:
                    if(x!=""):
                        tmp_utterance +=" "
                    tmp_utterance +=""+ x
                
            if(tmp_utterance != ""):
                name_utterance.append(tmp_utterance)
            #print("=".join(name_utterance))
            #out.write("\t".join(name_utterance)+"\n")
            if(len(name_utterance) <= 2 or '%%%' in name_utterance[0]):
                continue
            if name_utterance[0].split()[0] == name_utterance[2].split()[0]:
                #print("NOT a D:",name_utterance)
                continue
                
                
                
            while(len(name_utterance)<8):
                name_utterance.append("")
            to_be_printed.append(name_utterance + [MOVIE_NAME])
            #print("+".join(result))
            #out.write("\t".join(result)+"\n")
            #print(discovery,i)
            discovery+=1
            #if(discovery>50):
             #   break
    elif(line.count("(")>2):
        print("Line {0} has more than one (",i)
for i,l in enumerate(to_be_printed):
    if(i == len(to_be_printed)-1 or not (l[0]==to_be_printed[i+1][0] and l[1]==to_be_printed[i+1][1])):
        out.write("\t".join(l)+"\n")
# Out:
# Movie: Taxi Driver Screenplay: taxidriver
# printing original file to txt..
# Modifing the file...
# Remove unnecassary action(direction)s
# try..  801 It is 3:30 IN THE MORNING in a bacon-shaped all night WEST SIDE
# try..  802 REATAURANT. The thick smell hangs in the air - fried grease, smoke,
# try..  803 sweat, regurgitated wine.
# try..  804
# try..  805 Whatever doesn't flush away in New York at night turns up in places
# try..  806 like this. A burly grease-stained COOK stands over the grill. A JUNKIE
# try..  807 shuffles from one side of the door to another. Slouched over the small
# try..  808 four-person formica tables are several WELL-DRESSED BLACKS (too well- dressed for this time and place), a cluster of STREET PEOPLE and a lost
# try..  809
# try..  810
# try..  811 OLD COOT who hangs onto his cup of coffee as if it were his last
# try..  812 possession.
# try..  813
# try..  814 The restaurant, brightly lit, perfectly conveys the image urban
# try..  815 plasticity - without the slightest hint of an accompanying cleanliness.
# try..  816
# try..  817 Toward the rear of the restaurant sit three cabbies: WIZARD, a worn man
# try..  818 about fifty, DOUGH-BOY, younger family man, CHARLIE T., fourtyish
# try..  819 Black.
# try..  820
# try..  821 Wizard is telling Dough-Boy a story. Charlie T., his elbows popped
# try..  822 against table top, is not listening. He stares silently down at a plate
# try..  823 of cold scrambled eggs and a Racing Forum. His eyes may not be open.
# try..  824
# try..  825 WIZARD
# try..  826 First she did her make-up. You know, I hate it when they do that. I
# try..  827 mean she does the whole works, the mascara, the eye-shadow, the
# try..  828 lipstick, the rouge...
# try..  829
# try..  830 DOUGH-BOY
# try..  831 Not rouge. Blush-On, they call it.
# try..  832
# try..  833 WIZARD
# try..  834 The kind with a brush.
# try..  835
# try..  836 Travis appears at the door. He has to push aside the JUNKIES to enter
# try..  837 without making physical contact - something Travis would not relish. He
# try..  838 may be repulsed with these people and this place, but he is too much a
# try..  839 part of this to let his feelings rise to the surface.
# try..  840
# try..  841 Wizard gives Travis a perfunctory wave.
# try..  842
# try..  843 WIZARD
# try..  844 Travis.
# try..  845
# try..  846 TRAVIS
# try..  847 Hey Wizard.
# try..  848
# try..  849 Travis straddles a seat at the table. Dough-Boy gives Travis something
# try..  850 between a wink and an eye-twitch saying:
# try..  851
# try..  852 DOUGH-BOY
# try..  853 Yeah, that's Blush-On. My wife uses it,
# try..  854
# try..  855 WIZARD
# try..  856 (ironic)Ask Travis. He's the ladies man.
# try..  857
# try..  858 Travis shrugs and motions for a cup of coffee.
# try..  859
# try..  860 WIZARD
# try..  861 (continuing)Well, whatever the fuck it is, she used it. And then the
# try..  862 spray perfume. You know, the real sweat kind - and, on top of that, get
# try..  863 this, right when we're crossing the Tri-boro bridge - she changes her
# try..  864 pantyhose!
# try..  865
# try..  866 DOUGH-BOY
# try..  867 No.
# try..  868
# try..  869 Travis turns his head. He appears not to be interested, but is.
# try..  870
# try..  871 WIZARD
# try..  872 Yeah.
# try..  873
# try..  874 DOUGH-BOY
# try..  875 Could you see anything?
# try..  876
# try..  877 WIZARD
# try..  878 Well, she was trying to keep her skirt down, sort of, you know. But it
# try..  879 was pretty obvious what she was doing. I mean, Christ, it was rush hour
# try..  880 and the traffic's practically standing still.
# try..  881
# try..  882 DOUGH-BOY
# try..  883 What did you do?
# try..  884
# try..  885 WIZARD
# try..  886 Threw on the emergency, jumped the seat and fucked her brains out -
# try..  887 What do you think!(they laugh)What do I have to do? Draw you a picture?
# try..  888
# try..  889 DOUGH-BOY
# try..  890 Yeah.
# try..  891
# try..  892 WIZARD
# try..  893 What was I supposed to do? I was watching in the rear view. You know,
# try..  894 just checkin' traffic.(to Travis)So howsit?
# try..  895
# try..  896 TRAVIS
# try..  897 (w/o inflection)Some fleet driver for Bell just cut up. Just heard it
# try..  898 on the radio.
# try..  899
# try..  900 DOUGH-BOY
# try..  901 Stick up?
# try..  902
# try..  903 A WAITRESS brings Travis' coffee and a glass of water. He asks for a
# try..  904 cheeseburger.
# try..  905
# try..  906 WIZARD
# try..  907 Sure. What do you think? She wanted to get out of the cab. I said
# try..  908 "Look, you're in the middle of the fucking bridge..."
# try..  909
# try..  910 DOUGH-BOY
# try..  911 You said that?
# try..  912
# try..  913 WIZARD
# try..  914 Well, I said, "Lady, please, we're on a bridge..."
# try..  915
# try..  916 DOUGH-BOY
# try..  917 And what happened?
# try..  918
# try..  919 Travis awaits Wizard's answer.
# try..  920
# try..  921 WIZARD
# try..  922 She stayed in the cab, what's she gonna do? but she stiffed me. A real
# try..  923 skunk.
# try..  924
# try..  925 DOUGH-BOY
# try..  926 A real skunk.
# try..  927
# try..  928 Wizard realizes Travis and Dough-Boy may not have met.
# try..  929
# try..  930 WIZARD
# try..  931 (paternal) Travis, you know Dough-Boy, Charlie T.?
# try..  932
# try..  933 Charlie T. nods sleepily. Travis indicates he knows Dough-Boy.
# try..  934
# try..  935 DOUGH-BOY
# try..  936 Yeah. We went to Harvard together.(laughs)
# try..  937
# try..  938 WIZARD
# try..  939 We call him Dough-Boy cause he likes the dollars. He'll chase a buck
# try..  940 straight into Jersey.
# try..  941
# try..  942 DOUGH-BOY
# try..  943 Look who's talking?(gestures around table)Who else would stay up all
# try..  944 night to catch the morning rush hour?
# try..  945
# try..  946 Travis sips his coffee. Charlie T.'s eyelids slip shut.
# try..  947
# try..  948 TRAVIS
# try..  949 No, just some crazy fucker. Cut have his ear off.
# try..  950
# try..  951 DOUGH-BOY
# try..  952 Where.
# try..  953
# try..  954 TRAVIS
# try..  955 In the jungle. 122nd.
# try..  956
# try..  957 Travis' eyes turn toward the restaurant's other patrons.
# try..  958
# try..  959 POV: THREE STREET PEOPLE sitting at a table. One GUY, stoned, stares
# try..  960 straight ahead. A raggedly attractive GIRL rest her head on the
# try..  961 shoulder of the other, a heavily bearded YOUNG MAN with a headband.
# try..  962 They kiss and tease each other, momentarily lost in their separate
# try..  963 world.
# try..  964
# try..  965 Travis watches the hippie couple closely, his feeling sharply divided
# try..  966 between cultural contempt and morose jealousy. Why should these people
# try..  967 enjoy the love and intimacy that has always eluded him? He must enjoy
# try..  968 these schizoid emotions, because his eyes dwell on the couple.
# try..  969
# try..  970 DOUGH-BOY
# try..  971 (changing the subject)You run all over town, don't you, Travis?
# try..  972
# try..  973 WIZARD
# try..  974 (referring to 122nd St.)Fuckin' Mau Mau land, that's what it is.
# try..  975
# try..  976 Travis turns back to his companions.
# try..  977
# try..  978 TRAVIS
# try..  979 Huh?
# try..  980
# try..  981 DOUGH-BOY
# try..  982 I mean, you handle some pretty rough traffic, huh?
# try..  983
# try..  984 TRAVIS
# try..  985 (catching on)I have.
# try..  986
# try..  987 DOUGH-BOY
# try..  988 You carry a piece? You need one?
# try..  989
# try..  990 TRAVIS
# try..  991 Nah.(a beat)I suppose not.
# try..  992
# try..  993 Waitress slaps down smudge-marked glass of water, and a cheeseburger
# try..  994 plate that looks more like a shrunken head on a serving platter.
# try..  995
# try..  996 DOUGH-BOY
# try..  997 Well, you ever need one, I know a feller that kin getcha a real nice
# try..  998 deal. Lotsa shit around.
# try..  999
# Parsing..

# %%
out.close()
txtfile.close()
orgfile.close()
print("Done")
# Out:
# Done
