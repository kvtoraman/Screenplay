# %%
import docx2txt
import string

# %%
tmp_lines = []
def isAllCaps(line):
    for ch in line:
        if(ch.islower()):
            return False
    return True
def isActionWithOneLinebreak(line):
    if line == "":
        return True
    if line[0] =='(' or line[-1] ==')' or line[-1] != '.':
        return False
    
    if not isName(line):
        return True
        
    return False
def checkNext3Lines(i,lines):
    return (isActionWithOneLinebreak(lines[i+1]) and 
    isActionWithOneLinebreak(lines[i+2]) and
    isActionWithOneLinebreak(lines[i+3]))
def checkPrevious3Lines(i,lines):
    return (isActionWithOneLinebreak(lines[i-1]) and 
    isActionWithOneLinebreak(lines[i-2]) and
    isActionWithOneLinebreak(lines[i-3]) and
    not isName(lines[i-4]))

def isSceneChanger(line):#deteck scene changer lines
    sc_list = ["EXT.","INT.","DECK "," - ","ROOM","ELEVATOR","ON THE ","SLAM TO","INT/EXT","TITLE"]
    for sc in sc_list:
        if(sc in line):
            return True
    return False
def checkPreviousNonemptyLine(i,lines):
    #print(lines[i],"returns")
    while(lines[i-1] == ""):
        i -= 1
    i -= 1
    if i ==0:
        return True
    #print(i)
    
    #print(lines[i])
    if lines[i][0] =='(' and lines[i][-1] ==')':
        return True
    if isName(lines[i]):
        return True
    #print('False')
    return False
    
def isAction(i,lines):
    debug_line = 300
    #print("i-1,i-3=>",lines[i-1] , lines[i-2] , lines[i-3])
    if debug_line+200>i>debug_line:
        print("try.. ",i,lines[i])
    if(lines[i] == "" or i<4):
        return False
    if(i+3>=len(lines)):
        return False
    if( debug_line+200>i>debug_line ):
        print(lines[i])
    #if("--" in lines[i]):
     #   return False
    if lines[i][-1] == '?':
        return False
    if lines[i] == ' ' or lines[i] == '\t':
        return True
    if('(' is lines[i][0] or ')' is lines[i][-1]):
        return False
    if isName(lines[i-1]) or isName(lines[i-2]) or isName(lines[i-3]):
        return False
    if(isAllCaps(lines[i])):
        if ('!!' in lines[i] or lines[i][-1] == '.'):
            return True
        return False
    if( debug_line+200>i>debug_line ):
        print(lines[i])
    if(checkPrevious3Lines(i,lines)):
        if(checkNext3Lines(i,lines)):
    #        if(len(lines[i])<3):
    #            print('-',len(lines[i]),'-',lines[i],'-')
            if(not lines[i][1].isupper()):
                if debug_line+200>i>debug_line:
                    print("still try.. ",i,lines[i])
                if(checkPreviousNonemptyLine(i,lines)):
                    return False
                if(lines[i-4] == ""):
                    return True
                return True
    if( debug_line+200>i>debug_line ):
        print(lines[i])
    if isSceneChanger(lines[i-4]):
        return True
    if lines[i][0].islower():
        return False
    words_in_line = lines[i].split()
    for word in words_in_line:
        if(isName(word)):
            return True
        
    return False
def isName(name):
    if not isAllCaps(name):
        return False
    if isSceneChanger(name):
        return False
    if len(name)<3:
        return False
    return True
#todo:checks whether the file has errors or not
def errorInFile(lines):
    for line in lines:
        if(bool("(" in line) != bool(")" in line)):
            pass
            #print("(" in line , ")" in line)
            #print(line)
            #return True
    return False

# %%
MOVIE_NAME = "Ouija"
DOCX_NAME = "Ouija-09-26-13" #without extension
my_text = docx2txt.process(DOCX_NAME +".docx")
lines = my_text.split('\n')
out = open(DOCX_NAME + "_out.txt","w")
txtfile = open(DOCX_NAME + "_modified.txt","w")
orgfile = open(DOCX_NAME+ "_original.txt","w")
print("Movie:",MOVIE_NAME,"Screenplay:",DOCX_NAME)
discovery = 1
if(errorInFile(lines)):
    print("ERROR IN FILE")
    exit(1)
tmp_lines = []
print('printing original file to txt..')
for i,line in enumerate(lines):
    orgfile.write(lines[i]+'\n')
#remove tabs,(MORE),pagenumbers from text    
print("Modifing the file...")
for i,line in enumerate(lines):
    lines[i] = lines[i].replace("’","'")
    lines[i] = lines[i].replace('(MORE)','')#replace all (MORE)
    lines[i] = lines[i].replace('EXT:','EXT.') # default is 'EXT.', not 'EXT:'
    lines[i] = lines[i].replace("cont'd","CONT'D")
    lines[i] = lines[i].replace('JEEPERS CREEPERS','') #exception for 1 movie..
    if(lines[i]==''):
        continue
    lines[i] = lines[i].replace('\t',' ')#replace all tab characters with space
    if "Shooting Script" in lines[i]:
        lines[i] = ''
    if "CONTINUED" in lines[i]:
        lines[i] = ''
    if('BACK TO' in lines[i]):#erase those
        lines[i] = ''
    if('CLOSE ON' in lines[i]):#direction for camera
        lines[i] = ''
    if('DISSOLVE TO' in lines[i] or 'CUT ' in lines[i]):
        lines[i] = ''
    if('ONSCREEN' in lines[i] or 'FADE' in lines[i]):
        lines[i] = ''
    if('TO CAMERA' in lines[i]):# or 'to camera' in lines[i]
        lines[i] = ''
    if("(CONT'D)" in lines[i] and lines[i][-8:] != "(CONT'D)"):
        #print(lines[i])
        cont_splitted = lines[i].split("(CONT'D)")
        lines[i] = cont_splitted[0]
        lines.insert(i+1,"")
        lines.insert(i+2,cont_splitted[1][1:])
        #fix?
for i,line in enumerate(lines):
    #print(lines[i])
    if(len(lines[i])<1):
        continue
    while(len(lines[i])>=1 and lines[i][0] == ' '):#remove space if it's the first character
        #print("tab:",lines[i])
        lines[i] = lines[i][1:]
        #print("aft:",lines[i])
    if(2<=len(lines[i])<=5 and lines[i][-1] == '.' and  lines[i][:-1].isdigit()):#replace pagenumbers
        #print("page:",lines[i])
        lines[i] = ""
        continue
    if(1<=len(lines[i])<=4 and lines[i].isdigit()):#replace pagenumbers
        #print("page:",lines[i])
        lines[i] = ""
        continue    
    if(lines[i] != "" and ')' in lines[i] and '(' not in lines[i]):#find parantheticals that occupy more than oneline,merge them
        open_id = i
        #print("=>",lines[i-1],lines[i])
        while('(' not in lines[open_id]):
            open_id -= 1
        new_line = lines[open_id]+" "+lines[i]
        #print(new_line)
        for j in range(open_id,i+1):
            lines[j] = ""
        lines.insert(open_id,new_line)
    lines[i] = lines[i].replace('(voice over)','(V.O.)')
    if(lines[i][0:4] == "(O.S" or lines[i][0:4] == "(V.O"):# if O.S or V.O is the beginning of a line, append it to its speaker
        lines[i-2] +=" "+ lines[i]
        lines[i] = lines[i-2]
    
        
test = 988
#print("%".join(lines[test-10:test+10]))
print("Remove unnecassary action(direction)s")

for i,line in enumerate(lines):
    #remove action(direction)'s and 3 '\n' after them
    if(isAction(i,lines)):
    #    print(i,lines[i])
        continue
        #del lines[i:i+4]
        
    else:
        tmp_lines.append(lines[i])
    #if i > 1000:
     #   break
lines = tmp_lines
#print modified file to check
for i,line in enumerate(lines):
    txtfile.write(line+"\n")
print("Parsing..")
to_be_printed = []
for i,line in enumerate(lines):
    if('(' in line):
        if(isAllCaps(line)):
            continue
        if(line[0]=='(' and line[-1]==')' and line[1:10] == 'copyright'):
            continue
        if("CONT'D" not in line and "O.S." not in line and "V.O" not in line and "MORE" not in line):
            pre_emotion_empty_count = 0
            pre_step = 0
            pre_name_count = 0
            result = []
        
            while(pre_name_count < 1 or len(lines[i - pre_step]) < 3 or  not  isAllCaps(lines[i-pre_step])):
                if isAllCaps(lines[i-pre_step]) and len(lines[i-pre_step]) > 0:
                    pre_name_count += 1
                pre_step += 1
            if(isSceneChanger(lines[i-pre_step])):
                result.append("")
                result.append("")
                result.append("")
                pre_step-=1
                while(lines[i-pre_step] == ""):
                    pre_step-=1
                
            post_emotion_empty_count = 0
            post_step = 0
            post_name_count = 0

            while(post_name_count < 2 or len(lines[i + post_step]) < 3 or  not  isAllCaps(lines[i+post_step]) ):
                if isSceneChanger(lines[i+post_step]) :
                    break
                if isAllCaps(lines[i+post_step]) and len(lines[i+post_step]) > 0:
                    post_name_count += 1
                post_step += 1
            while isSceneChanger(lines[i+post_step]):
                post_step -=1
            
            #print(lines[i-pre_step:i+post_step])
            #print(pre_step,post_step)
            printed_lines = lines[i-pre_step:i+post_step]
            
            for line_in_range in lines[i-pre_step:i+post_step]:
                if(line_in_range!="" and not line_in_range[:-1].isnumeric()):
                    if(line_in_range!="(O.S.)"):
                        if(len(result)%3 == 1 and result[-1][0] != '(' and line_in_range[0]!='('):
                            result.append("")
                        result.append(line_in_range)
            name_utterance = []
            tmp_utterance = "%%%"
            for x in result:
                if(isName(x)):
                    if(tmp_utterance != "%%%"):
                        name_utterance.append(tmp_utterance)
                    tmp_utterance = ""
                    name_utterance.append(x)
                else:
                    if(x!=""):
                        tmp_utterance +=" "
                    tmp_utterance +=""+ x
                
            if(tmp_utterance != ""):
                name_utterance.append(tmp_utterance)
            #print("=".join(name_utterance))
            #out.write("\t".join(name_utterance)+"\n")
            if(len(name_utterance) <= 2 or '%%%' in name_utterance[0]):
                continue
            if name_utterance[0].split()[0] == name_utterance[2].split()[0]:
                #print("NOT a D:",name_utterance)
                continue
                
                
                
            while(len(name_utterance)<8):
                name_utterance.append("")
            to_be_printed.append(name_utterance + [MOVIE_NAME])
            #print("+".join(result))
            #out.write("\t".join(result)+"\n")
            #print(discovery,i)
            discovery+=1
            #if(discovery>50):
             #   break
    elif(line.count("(")>2):
        print("Line {0} has more than one (",i)
for i,l in enumerate(to_be_printed):
    if(i == len(to_be_printed)-1 or not (l[0]==to_be_printed[i+1][0] and l[1]==to_be_printed[i+1][1])):
        out.write("\t".join(l)+"\n")
# Out:
# Movie: Ouija Screenplay: Ouija-09-26-13
# printing original file to txt..
# Modifing the file...
# Remove unnecassary action(direction)s
# try..  301
# try..  302
# try..  303
# try..  304 It's early. Laine sits alone in the classroom. !Outside the commotion of students arriving for the school day. !Laughing distant voices. Slamming of lockers out in the hallway.
# It's early. Laine sits alone in the classroom. !Outside the commotion of students arriving for the school day. !Laughing distant voices. Slamming of lockers out in the hallway.
# It's early. Laine sits alone in the classroom. !Outside the commotion of students arriving for the school day. !Laughing distant voices. Slamming of lockers out in the hallway.
# still try..  304 It's early. Laine sits alone in the classroom. !Outside the commotion of students arriving for the school day. !Laughing distant voices. Slamming of lockers out in the hallway.
# try..  305
# try..  306
# try..  307
# try..  308
# try..  309
# try..  310
# try..  311
# try..  312
# try..  313
# try..  314 Laine regards another blank piece of paper. She takes a breath. Writes out another note. Her final words are the only ones we see: “Friends forever xoxo Laine”
# Laine regards another blank piece of paper. She takes a breath. Writes out another note. Her final words are the only ones we see: “Friends forever xoxo Laine”
# Laine regards another blank piece of paper. She takes a breath. Writes out another note. Her final words are the only ones we see: “Friends forever xoxo Laine”
# still try..  314 Laine regards another blank piece of paper. She takes a breath. Writes out another note. Her final words are the only ones we see: “Friends forever xoxo Laine”
# try..  315
# try..  316
# try..  317
# try..  318 Laine folds the paper into an origami note. !She sets it on a far desk near the window as the bell rings and students start filtering into the classroom.
# Laine folds the paper into an origami note. !She sets it on a far desk near the window as the bell rings and students start filtering into the classroom.
# Laine folds the paper into an origami note. !She sets it on a far desk near the window as the bell rings and students start filtering into the classroom.
# still try..  318 Laine folds the paper into an origami note. !She sets it on a far desk near the window as the bell rings and students start filtering into the classroom.
# try..  319
# try..  320
# try..  321
# try..  322 A MOMENT LATER. Laine's back in her desk. ISABELLE (17) takes the seat next to her and starts right in --
# A MOMENT LATER. Laine's back in her desk. ISABELLE (17) takes the seat next to her and starts right in --
# A MOMENT LATER. Laine's back in her desk. ISABELLE (17) takes the seat next to her and starts right in --
# still try..  322 A MOMENT LATER. Laine's back in her desk. ISABELLE (17) takes the seat next to her and starts right in --
# try..  323
# try..  324
# try..  325
# try..  326 ISABELLE
# ISABELLE
# try..  327
# try..  328 What are we feeling this weekend?
# What are we feeling this weekend?
# try..  329
# try..  330
# try..  331
# try..  332 LAINE
# LAINE
# try..  333
# try..  334 It's only Tuesday.
# It's only Tuesday.
# try..  335
# try..  336
# try..  337
# try..  338 ISABELLE
# ISABELLE
# try..  339
# try..  340 I know. But I like to get a jump. (scrolling through her phone)
# I know. But I like to get a jump. (scrolling through her phone)
# try..  341
# try..  342
# try..  343
# try..  344 Got multiple party options here.
# Got multiple party options here.
# Got multiple party options here.
# Got multiple party options here.
# try..  345
# try..  346 Small selective gathering or that
# Small selective gathering or that
# Small selective gathering or that
# Small selective gathering or that
# try..  347
# try..  348 blow-out everyone's going to?
# blow-out everyone's going to?
# try..  349
# try..  350
# try..  351
# try..  352 A GUY swoops in and gives Laine a kiss before taking the desk behind her. This is TREVOR (17).
# A GUY swoops in and gives Laine a kiss before taking the desk behind her. This is TREVOR (17).
# A GUY swoops in and gives Laine a kiss before taking the desk behind her. This is TREVOR (17).
# still try..  352 A GUY swoops in and gives Laine a kiss before taking the desk behind her. This is TREVOR (17).
# try..  353
# try..  354
# try..  355
# try..  356 TREVOR
# TREVOR
# try..  357
# try..  358 She trying to steal my time again? Iz, we don't always have to tag along. You can fly solo.
# She trying to steal my time again? Iz, we don't always have to tag along. You can fly solo.
# try..  359
# try..  360
# try..  361
# try..  362 ISABELLE
# ISABELLE
# try..  363
# try..  364 Yeah. Me showing up to a party alone wouldn't look pathetic at all. Not everyone has your perfect couple situation.
# Yeah. Me showing up to a party alone wouldn't look pathetic at all. Not everyone has your perfect couple situation.
# try..  365
# try..  366
# try..  367
# try..  368 LAINE
# LAINE
# try..  369
# try..  370 Look at her... acting like she's
# Look at her... acting like she's
# try..  371
# try..  372 not the one who breaks up with
# not the one who breaks up with
# not the one who breaks up with
# not the one who breaks up with
# try..  373
# try..  374
# try..  375
# try..  376 every guy she goes out with.
# every guy she goes out with.
# every guy she goes out with.
# still try..  376 every guy she goes out with.
# try..  377
# try..  378
# try..  379
# try..  380 ISABELLE
# ISABELLE
# try..  381
# try..  382 I'm a picky bitch. Can't help it.
# I'm a picky bitch. Can't help it.
# try..  383
# try..  384
# try..  385
# try..  386 A TEACHER, MR. SATLOF, enters and starts passing out an exam.
# A TEACHER, MR. SATLOF, enters and starts passing out an exam.
# A TEACHER, MR. SATLOF, enters and starts passing out an exam.
# still try..  386 A TEACHER, MR. SATLOF, enters and starts passing out an exam.
# try..  387
# try..  388
# try..  389
# try..  390 MR. SATLOF
# MR. SATLOF
# try..  391
# try..  392 Okay. Settle. Books away. I'm putting thirty minutes on the clock. Please dazzle me with your knowledge of all things John Milton.
# Okay. Settle. Books away. I'm putting thirty minutes on the clock. Please dazzle me with your knowledge of all things John Milton.
# try..  393
# try..  394
# try..  395
# try..  396 Trevor leans in toward Laine, whispering --
# Trevor leans in toward Laine, whispering --
# Trevor leans in toward Laine, whispering --
# still try..  396 Trevor leans in toward Laine, whispering --
# try..  397
# try..  398
# try..  399
# try..  400
# try..  401
# try..  402
# try..  403
# try..  404 TREVOR
# TREVOR
# try..  405
# try..  406 Yo. You ready to throw down on
# Yo. You ready to throw down on
# try..  407
# try..  408 this iambic pentameter --
# this iambic pentameter --
# this iambic pentameter --
# this iambic pentameter --
# try..  409
# try..  410
# try..  411
# try..  412 But Laine's not paying attention. She's glancing back at the desk where she put the note... and it's still empty. The note just sitting there.
# But Laine's not paying attention. She's glancing back at the desk where she put the note... and it's still empty. The note just sitting there.
# But Laine's not paying attention. She's glancing back at the desk where she put the note... and it's still empty. The note just sitting there.
# still try..  412 But Laine's not paying attention. She's glancing back at the desk where she put the note... and it's still empty. The note just sitting there.
# try..  413
# try..  414
# try..  415
# try..  416 TREVOR (CONT'D)
# TREVOR (CONT'D)
# try..  417
# try..  418 Laine? This is the part where you laugh.
# Laine? This is the part where you laugh.
# try..  419
# try..  420
# try..  421
# try..  422 Laine snaps out of it. Gives Trevor a smile.
# Laine snaps out of it. Gives Trevor a smile.
# Laine snaps out of it. Gives Trevor a smile.
# still try..  422 Laine snaps out of it. Gives Trevor a smile.
# try..  423
# try..  424
# try..  425
# try..  426 MR. SATLOF
# MR. SATLOF
# try..  427
# try..  428 Eyes front. No talking.
# Eyes front. No talking.
# try..  429
# try..  430
# try..  431
# try..  432
# try..  433
# try..  434
# try..  435
# try..  436 LAINE TAKING HER TEST. She hears whispering and looks up to see her TEACHER out in the hall talking with someone.
# LAINE TAKING HER TEST. She hears whispering and looks up to see her TEACHER out in the hall talking with someone.
# LAINE TAKING HER TEST. She hears whispering and looks up to see her TEACHER out in the hall talking with someone.
# LAINE TAKING HER TEST. She hears whispering and looks up to see her TEACHER out in the hall talking with someone.
# try..  437
# try..  438
# try..  439
# try..  440 Mr. Satlof comes back into the classroom, and by his somber expression, Laine knows that something is wrong.
# Mr. Satlof comes back into the classroom, and by his somber expression, Laine knows that something is wrong.
# Mr. Satlof comes back into the classroom, and by his somber expression, Laine knows that something is wrong.
# still try..  440 Mr. Satlof comes back into the classroom, and by his somber expression, Laine knows that something is wrong.
# try..  441
# try..  442
# try..  443
# try..  444 MR. SATLOF (CONT'D)
# MR. SATLOF (CONT'D)
# try..  445
# try..  446 I know some of you are finishing up, but... I have something I need to share with everyone.
# I know some of you are finishing up, but... I have something I need to share with everyone.
# try..  447
# try..  448
# try..  449
# try..  450 Students put their pencils down. Murmuring, wondering what's going on.
# Students put their pencils down. Murmuring, wondering what's going on.
# Students put their pencils down. Murmuring, wondering what's going on.
# still try..  450 Students put their pencils down. Murmuring, wondering what's going on.
# try..  451
# try..  452
# try..  453
# try..  454 MR. SATLOF (CONT'D)
# MR. SATLOF (CONT'D)
# try..  455
# try..  456 I just got word that...
# I just got word that...
# try..  457
# try..  458
# try..  459
# try..  460 Mr. Satlof's voice trails off. This is hard for him to say.
# Mr. Satlof's voice trails off. This is hard for him to say.
# Mr. Satlof's voice trails off. This is hard for him to say.
# still try..  460 Mr. Satlof's voice trails off. This is hard for him to say.
# try..  461
# try..  462
# try..  463
# try..  464 Laine glances back again at the EMPTY DESK. Then --
# Laine glances back again at the EMPTY DESK. Then --
# Laine glances back again at the EMPTY DESK. Then --
# still try..  464 Laine glances back again at the EMPTY DESK. Then --
# try..  465
# try..  466
# try..  467
# try..  468 LAINE
# LAINE
# try..  469
# try..  470 It's Debbie, isn't it? What
# It's Debbie, isn't it? What
# try..  471
# try..  472 happened?
# happened?
# try..  473
# try..  474
# try..  475
# try..  476 Now everyone's looking at Laine. Mr. Satlof slowly nods.
# Now everyone's looking at Laine. Mr. Satlof slowly nods.
# Now everyone's looking at Laine. Mr. Satlof slowly nods.
# still try..  476 Now everyone's looking at Laine. Mr. Satlof slowly nods.
# try..  477
# try..  478
# try..  479
# try..  480 MR. SATLOF
# MR. SATLOF
# try..  481
# try..  482 I'm so sorry... she died at her
# I'm so sorry... she died at her
# try..  483
# try..  484 house last night.
# house last night.
# house last night.
# house last night.
# try..  485
# try..  486
# try..  487
# try..  488 TREVOR
# TREVOR
# try..  489
# try..  490 Oh my God...
# Oh my God...
# try..  491
# try..  492
# try..  493
# try..  494 Reaction ripples through the classroom. Isabelle starts crying. But Laine is frozen.
# Reaction ripples through the classroom. Isabelle starts crying. But Laine is frozen.
# Reaction ripples through the classroom. Isabelle starts crying. But Laine is frozen.
# still try..  494 Reaction ripples through the classroom. Isabelle starts crying. But Laine is frozen.
# try..  495
# try..  496
# try..  497
# try..  498
# try..  499
# Parsing..

# %%
out.close()
txtfile.close()
orgfile.close()
print("Done")
# Out:
# Done
