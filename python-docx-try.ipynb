# %%
from docx import Document
f = open('Boyhood-screenplay-11-14-FINAL.docx', 'rb')
document = Document(f)
f.close()

# %%
print(type(document))
# Out:
# <class 'docx.document.Document'>

# %%
document.paragraphs
# Out:
# ...
#  ...]
